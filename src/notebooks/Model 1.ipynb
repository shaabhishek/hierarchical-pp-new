# %%
import torch
import torch.nn as nn
from torch.optim import Adam
import torch.nn.functional as F
from torch.distributions import kl_divergence, Normal, Categorical

# %%
import sys
sys.path.insert(0, './../')

# %%
from base_model import compute_marker_log_likelihood, compute_point_log_likelihood, generate_marker
from utils.metric import get_marker_metric, compute_time_expectation, get_time_metric

# %%
torch.__version__
# Out:
# '1.0.1.post2'

# %%
print(torch.cuda.is_available())
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# True

# %%
def sample_gumbel(shape, eps=1e-20):
    unif = torch.rand(*shape).to(device)
    g = -torch.log(-torch.log(unif + eps))
    return g

def sample_gumbel_softmax(logits, temperature):
    """
        Input:
        logits: Tensor of log probs, shape = BS x k
        temperature = scalar
        
        Output: Tensor of values sampled from Gumbel softmax.
                These will tend towards a one-hot representation in the limit of temp -> 0
                shape = BS x k
    """
    g = sample_gumbel(logits.shape)
    assert g.shape == logits.shape
    h = (g + logits)/temperature
    y = F.softmax(h, dim=-1)
    return y

def reparameterize(mu, logvar):
        epsilon = torch.randn_like(mu).to(device)
        sigma = torch.exp(0.5 * logvar)
        return mu + epsilon.mul(sigma)

# %%
class Model1(nn.Module):
    def __init__(self, latent_dim=20, marker_dim=31, marker_type='real', hidden_dim=128, time_dim=2, n_cluster=5, x_given_t=False, time_loss='normal', gamma=1., dropout=None, base_intensity=None, time_influence=None):
        super().__init__()
        self.marker_type = marker_type
        self.marker_dim = marker_dim
        self.time_dim = time_dim
        self.hidden_dim = hidden_dim
        self.latent_dim = latent_dim
        self.cluster_dim = n_cluster
        self.x_given_t = x_given_t
        self.time_loss = time_loss
        self.sigma_min = 1e-2
        self.gamma = gamma
        self.dropout = dropout
        
        # Preprocessing networks
        # Embedding network
        self.x_embedding_layer = [128]
        self.t_embedding_layer = [8]
        self.embed_x, self.embed_t = self.create_embedding_nets()
        self.shared_output_layers = [256]
        self.inf_pre_module, self.gen_pre_module = self.create_preprocess_nets()
        
        # Forward RNN
        self.rnn = self.create_rnn()
        
        # Inference network
        self.encoder_layers = [64, 64]
        self.y_encoder, self.encoder_rnn, self.z_intmd_module, self.z_mu_module, self.z_logvar_module = self.create_inference_nets()
        
        # Generative network
        self.time_mu, self.time_logvar, self.output_x_mu, self.output_x_logvar = self.create_output_nets()
    
    def create_embedding_nets(self):
        # marker_dim is passed. timeseries_dim is 2
        if self.marker_type == 'categorical':
            x_module = nn.Embedding(self.marker_dim, self.x_embedding_layer[0])
        else:
            x_module = nn.Sequential(
                nn.Linear(self.marker_dim, self.x_embedding_layer[0]),
                nn.ReLU(),
        )
        
        t_module = nn.Sequential(
            nn.Linear(self.time_dim, self.t_embedding_layer[0]),
            nn.ReLU()
        )
        return x_module, t_module
    
    def create_preprocess_nets(self):
        # Inference net preprocessing
        hxty_input_dim = self.hidden_dim+self.x_embedding_layer[-1]+self.t_embedding_layer[-1]+self.cluster_dim
        inf_pre_module = nn.Linear(hxty_input_dim, hxty_input_dim)
        
        # Generative net preprocessing
        hzy_input_dim = self.hidden_dim+self.latent_dim+self.cluster_dim
        gen_pre_module = nn.Sequential(
            nn.ReLU(),nn.Dropout(self.dropout),
            nn.Linear(hzy_input_dim, self.shared_output_layers[-1]),
            nn.ReLU(),nn.Dropout(self.dropout))
        return inf_pre_module, gen_pre_module
        
    
    def create_rnn(self):
        rnn = nn.GRU(
            input_size=self.x_embedding_layer[-1]+self.t_embedding_layer[-1],
            hidden_size=self.hidden_dim,
        )
        return rnn
    
    def create_inference_nets(self):
        y_module = nn.Sequential(
            nn.Linear(self.hidden_dim, self.cluster_dim),
            nn.LogSoftmax(dim=-1)
        )
        
        encoder_rnn = nn.GRU(
            input_size=self.x_embedding_layer[-1]+self.t_embedding_layer[-1],
            hidden_size=self.hidden_dim,
        )
        
        z_input_dim = self.hidden_dim+self.x_embedding_layer[-1]+self.t_embedding_layer[-1]+self.cluster_dim
        z_intmd_module = nn.Sequential(
            nn.Linear(z_input_dim, self.encoder_layers[0]),
            nn.ReLU(),
            nn.Linear(self.encoder_layers[0], self.encoder_layers[1]),
            nn.ReLU(),
        )
        z_mu_module = nn.Linear(self.encoder_layers[1], self.latent_dim)
        z_logvar_module = nn.Linear(self.encoder_layers[1], self.latent_dim)
        return y_module, encoder_rnn, z_intmd_module, z_mu_module, z_logvar_module

    def create_output_nets(self):
        l = self.shared_output_layers[-1]
        t_module_mu = nn.Linear(l, 1)
        t_module_logvar = nn.Linear(l, 1)
        
        x_module_logvar = None
        if self.x_given_t:
            l += 1
        if self.marker_type == 'real':
            x_module_mu = nn.Linear(l, self.marker_dim)
            x_module_logvar = nn.Linear(l, self.marker_dim)
        elif self.marker_type == 'binary':#Fix binary
            x_module_mu = nn.Sequential(
                nn.Linear(l, self.marker_dim),
                nn.Sigmoid())
        elif self.marker_type == 'categorical':
            x_module_mu = nn.Sequential(
                nn.Linear(l, self.marker_dim)#,
                #nn.Softmax(dim=-1)
            )
        return t_module_mu, t_module_logvar, x_module_mu, x_module_logvar
    
    ### ENCODER ###
    def encoder(self, phi_xt, temp):
        """
        Input:
            phi_xt: Tensor of shape T x BS x (self.x_embedding_layer[-1]+self.t_embedding_layer[-1])
            temp: scalar
        Output:
            sample_y: Tensor of shape T x BS x cluster_dim
            sample_z: Tensor of shape T x BS x latent_dim
            logits_y: Tensor of shape 1 x BS x cluster_dim
            mu_z: Tensor of shape T x BS x latent_dim
            logvar_z: Tensor of shape T x BS x latent_dim
        """
        T,BS,_ = phi_xt.shape

        # Compute encoder RNN hidden states
        h_0 = torch.zeros(1, BS, self.hidden_dim).to(device)
        hidden_seq, _ = self.encoder_rnn(phi_xt, h_0)
        hidden_seq = torch.cat([h_0, hidden_seq], dim=0)
        
        # Encoder for y
        logits_y = self.y_encoder(hidden_seq[-1])[None, :, :] #shape(logits_y) = 1 x BS x k
        #shape(sample_y) = 1 x BS x k. Should tend to one-hot in the last dimension
        sample_y = sample_gumbel_softmax(logits_y, temp)
        repeat_vals = (T, -1,-1)
        sample_y = sample_y.expand(*repeat_vals) #T x BS x k
        
        # Encoder for z
        concat_hxty = torch.cat([hidden_seq[:-1], phi_xt, sample_y], dim=-1)
        phi_hxty = self.inf_pre_module(concat_hxty)
        z_intmd = self.z_intmd_module(phi_hxty)
        mu_z = self.z_mu_module(z_intmd)
        logvar_z = self.z_logvar_module(z_intmd)
        sample_z = reparameterize(mu_z, logvar_z)
        return sample_y, sample_z, logits_y, (mu_z, logvar_z)
    
    def forward(self, marker_seq, time_seq, anneal=1., mask=None, temp=0.5):
        time_log_likelihood, marker_log_likelihood, KL, metric_dict = self._forward(marker_seq, time_seq, temp, mask)

        marker_loss = (-1.* marker_log_likelihood *mask)[1:,:].sum()
        time_loss = (-1. *time_log_likelihood *mask)[1:,:].sum()
        
        NLL = self.gamma*time_loss + marker_loss
        loss = NLL + KL
        true_loss = time_loss + marker_loss
        meta_info = {"marker_ll":marker_loss.detach().cpu(), "time_ll":time_loss.detach().cpu(), "true_ll": true_loss.detach().cpu(), "kl": KL.detach().cpu()}
        return loss, {**meta_info, **metric_dict}
    
    def _forward(self, x, t, temp, mask):
        # Transform markers and timesteps into the embedding spaces
        phi_x, phi_t = self.embed_x(x), self.embed_t(t)
        phi_xt = torch.cat([phi_x, phi_t], dim=-1)
        T,BS,_ = phi_x.shape
                
        ## Inference
        # Get the sampled value and (mean + var) latent variable
        # using the hidden state sequence
        posterior_sample_y, posterior_sample_z, posterior_logits_y, (posterior_mu_z, posterior_logvar_z) = self.encoder(phi_xt, temp)

        repeat_vals = (T, -1,-1)
        posterior_logits_y = posterior_logits_y.expand(*repeat_vals)
        # Create distributions for Posterior random vars
        posterior_dist_z = Normal(posterior_mu_z, torch.exp(posterior_logvar_z*0.5))
        posterior_dist_y = Categorical(logits=posterior_logits_y)
        
        # Prior is just a Normal(0,1) dist for z and Uniform Categorical for y
        prior_dist_z = Normal(0.*posterior_mu_z, 1. + 0.*posterior_mu_z)
        prior_dist_y = Categorical(probs=1/self.cluster_dim + 0.*posterior_logits_y)

        ## Generative Part
        
        # Use the embedded markers and times to create another set of 
        # hidden vectors. Can reuse the h_0 and time_marker combined computed above

        # Run RNN over the concatenated embedded sequence
        h_0 = torch.zeros(1, BS, self.hidden_dim).to(device)
        # Run RNN
        hidden_seq, _ = self.rnn(phi_xt, h_0)
        # Append h_0 to h_1 .. h_T
        hidden_seq = torch.cat([h_0, hidden_seq], dim=0)
        
        # Combine (z_t, h_t, y) form the input for the generative part
        concat_hzy = torch.cat([hidden_seq[:-1], posterior_sample_z, posterior_sample_y], dim=-1)
        phi_hzy = self.gen_pre_module(concat_hzy)
        mu_marker, logvar_marker = generate_marker(self, phi_hzy, None)
        time_log_likelihood, mu_time = compute_point_log_likelihood(self, phi_hzy, t)
        marker_log_likelihood = compute_marker_log_likelihood(self, x, mu_marker, logvar_marker)
        
        KL_cluster = kl_divergence(posterior_dist_y, prior_dist_y)*mask
        KL_z = kl_divergence(posterior_dist_z, prior_dist_z).sum(-1)*mask
        KL = KL_cluster.sum() + KL_z.sum()
        try:
            assert (KL >= 0)
        except:
            import pdb; pdb.set_trace()
        metric_dict = {}
        with torch.no_grad():
            if self.time_loss == 'intensity':
                mu_time = compute_time_expectation(self, hidden_seq, t, mask)[:,:, None]
            get_marker_metric(self.marker_type, mu_marker, x, mask, metric_dict)
            get_time_metric(mu_time,  t, mask, metric_dict)
            
        return time_log_likelihood, marker_log_likelihood, KL, metric_dict

# %%
from trainer import train

# %%
def trainer(model, data = None, val_data=None, lr= 1e-3, l2_reg=1e-2, epoch = 400, batch_size = 32):

    optimizer = Adam(model.parameters(), lr=lr, weight_decay=l2_reg)

    for epoch_number in range(epoch):
        for i in range(0, len(data), batch_size):
            optimizer.zero_grad()
            loss, metrics = model(data['x'][i:i+batch_size], data['t'][i:i+batch_size], mask=mask)
            loss.backward()
            optimizer.step()
            print("loss:", loss.detach().cpu()/reduce(lambda x,y: x*y, data['x'].shape[0:2]))
            print(metrics)
#         train(model, epoch_number, data, optimizer, batch_size, val_data)
    return model

# %%
from functools import reduce

# %%
def main(model, data, val_data):
#     model = model().to(device)
#     data, _ = generate_mpp(type='hawkes', num_sample=1000)
#     val_data, _ = generate_mpp(type='hawkes', num_sample = 200)
#     print("Times: Data Shape: {}, Val Data Shape: {}".format(data['t'].shape, val_data['t'].shape))
#     print("Markers: Data Shape: {}, Val Data Shape: {}".format(data['x'].shape, val_data['x'].shape))
    trainer(model, data=data, val_data=val_data)

# %%
model = Model1(marker_dim=22, time_dim=2).to(device)
x,t = torch.rand(10, 32, 22).to(device), torch.rand(10, 32, 2).to(device)
data = {"x": x, "t": t}
mask = torch.ones(10,32).to(device)
main(model, data, None)
# Out:
# loss: tensor(25.1965)
# {'marker_ll': tensor(7687.7861), 'time_ll': tensor(344.4263), 'true_ll': tensor(8032.2124), 'kl': tensor(30.6646), 'marker_mse': array(2473.9775, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(92.71465, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(24.1855)
# {'marker_ll': tensor(7378.2627), 'time_ll': tensor(334.5691), 'true_ll': tensor(7712.8315), 'kl': tensor(26.5300), 'marker_mse': array(2101.4514, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(80.322495, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(23.1243)
# {'marker_ll': tensor(7056.9346), 'time_ll': tensor(318.2906), 'true_ll': tensor(7375.2251), 'kl': tensor(24.5386), 'marker_mse': array(1779.2332, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(60.76291, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(21.8511)
# {'marker_ll': tensor(6666.3711), 'time_ll': tensor(302.2912), 'true_ll': tensor(6968.6621), 'kl': tensor(23.7036), 'marker_mse': array(1429.1243, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(45.213665, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(20.3865)
# {'marker_ll': tensor(6218.9951), 'time_ll': tensor(281.5692), 'true_ll': tensor(6500.5645), 'kl': tensor(23.1254), 'marker_mse': array(1136.104, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(30.643797, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(18.8415)
# {'marker_ll': tensor(5739.5552), 'time_ll': tensor(266.3468), 'true_ll': tensor(6005.9019), 'kl': tensor(23.3654), 'marker_mse': array(968.79395, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(31.427242, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(17.7364)
# {'marker_ll': tensor(5401.6152), 'time_ll': tensor(250.4020), 'true_ll': tensor(5652.0171), 'kl': tensor(23.6318), 'marker_mse': array(1056.5494, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(39.228455, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor
dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-14.9679)
# {'marker_ll': tensor(-4637.7852), 'time_ll': tensor(-154.2533), 'true_ll': tensor(-4792.0386), 'kl': tensor(2.3035), 'marker_mse': array(179.12814, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.682202, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-15.2331)
# {'marker_ll': tensor(-4705.3032), 'time_ll': tensor(-171.6307), 'true_ll': tensor(-4876.9341), 'kl': tensor(2.3326), 'marker_mse': array(178.68979, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.5050387, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-15.3275)
# {'marker_ll': tensor(-4745.3491), 'time_ll': tensor(-161.8491), 'true_ll': tensor(-4907.1982), 'kl': tensor(2.4037), 'marker_mse': array(178.10376, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.8788896, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-15.6890)
# {'marker_ll': tensor(-4845.2236), 'time_ll': tensor(-177.7686), 'true_ll': tensor(-5022.9922), 'kl': tensor(2.5185), 'marker_mse': array(176.9806, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.5630636, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-15.3473)
# {'marker_ll': tensor(-4737.2334), 'time_ll': tensor(-176.2675), 'true_ll': tensor(-4913.5010), 'kl': tensor(2.3688), 'marker_mse': array(177.58575, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.4693093, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-15.3794)
# {'marker_ll': tensor(-4751.8340), 'time_ll': tensor(-172.1799), 'true_ll': tensor(-4924.0137), 'kl': tensor(2.5907), 'marker_mse': array(178.11069, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.5663776, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-15.8811)
# {'marker_ll': tensor(-4897.8760), 'time_ll': tensor(-186.4544), 'true_ll': tensor(-5084.3306), 'kl': tensor(2.3939), 'marker_mse': array(176.16907, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.290533, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-16.0423)
# {'marker_ll': tensor(-4971.0620), 'time_ll': tensor(-164.6759), 'true_ll': tensor(-5135.7378), 'kl': tensor(2.2120), 'marker_mse': array(174.38794, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.8534427, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-16.7131)
# {'marker_ll': tensor(-5179.8608), 'time_ll': tensor(-170.3916), 'true_ll': tensor(-5350.2524), 'kl': tensor(2.0703), 'marker_mse': array(171.56953, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.4370384, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-16.8689)
# {'marker_ll': tensor(-5230.4468), 'time_ll': tensor(-169.5415), 'true_ll': tensor(-5399.9883), 'kl': tensor(1.9507), 'marker_mse': array(170.92923, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.3785763, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-16.6137)
# {'marker_ll': tensor(-5158.1484), 'time_ll': tensor(-160.1082), 'true_ll': tensor(-5318.2568), 'kl': tensor(1.8725), 'marker_mse': array(171.60597, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.8020024, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-17.1590)
# {'marker_ll': tensor(-5303.5273), 'time_ll': tensor(-189.1387), 'true_ll': tensor(-5492.6660), 'kl': tensor(1.7774), 'marker_mse': array(170.51947, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.060778, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-17.4729)
# {'marker_ll': tensor(-5404.5688), 'time_ll': tensor(-188.4857), 'true_ll': tensor(-5593.0547), 'kl': tensor(1.7145), 'marker_mse': array(169.15405, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.118106, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-17.5787)
# {'marker_ll': tensor(-5435.5903), 'time_ll': tensor(-191.2568), 'true_ll': tensor(-5626.8472), 'kl': tensor(1.6739), 'marker_mse': array(168.64233, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.996776, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-17.0677)
# {'marker_ll': tensor(-5269.7446), 'time_ll': tensor(-193.5605), 'true_ll': tensor(-5463.3052), 'kl': tensor(1.6516), 'marker_mse': array(169.67728, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.9841943, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-15.1396)
# {'marker_ll': tensor(-4650.2676), 'time_ll': tensor(-196.0492), 'true_ll': tensor(-4846.3169), 'kl': tensor(1.6490), 'marker_mse': array(174.78656, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.9486694, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-12.1468)
# {'marker_ll': tensor(-3695.4424), 'time_ll': tensor(-193.1936), 'true_ll': tensor(-3888.6360), 'kl': tensor(1.6614), 'marker_mse': array(181.52771, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.939089, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-10.9326)
# {'marker_ll': tensor(-3333.7925), 'time_ll': tensor(-166.3923), 'true_ll': tensor(-3500.1848), 'kl': tensor(1.7591), 'marker_mse': array(194.1769, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.4546046, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-14.7359)
# {'marker_ll': tensor(-4551.0225), 'time_ll': tensor(-166.3876), 'true_ll': tensor(-4717.4102), 'kl': tensor(1.9075), 'marker_mse': array(179.56876, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.684679, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-15.2063)
# {'marker_ll': tensor(-4706.4692), 'time_ll': tensor(-161.7999), 'true_ll': tensor(-4868.2690), 'kl': tensor(2.2377), 'marker_mse': array(177.74963, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.892058, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-14.1595)
# {'marker_ll': tensor(-4348.4907), 'time_ll': tensor(-185.0712), 'true_ll': tensor(-4533.5620), 'kl': tensor(2.5178), 'marker_mse': array(187.75536, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.9588385, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-15.6283)
# {'marker_ll': tensor(-4851.3145), 'time_ll': tensor(-152.1430), 'true_ll': tensor(-5003.4575), 'kl': tensor(2.4110), 'marker_mse': array(174.98419, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.5685215, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-15.5121)
# {'marker_ll': tensor(-4775.2031), 'time_ll': tensor(-191.0546), 'true_ll': tensor(-4966.2578), 'kl': tensor(2.3829), 'marker_mse': array(173.83615, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.680623, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-15.4426)
# {'marker_ll': tensor(-4762.2734), 'time_ll': tensor(-181.8772), 'true_ll': tensor(-4944.1504), 'kl': tensor(2.5087), 'marker_mse': array(177.33722, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.1870527, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-16.2236)
# {'marker_ll': tensor(-4997.1709), 'time_ll': tensor(-197.0060), 'true_ll': tensor(-5194.1768), 'kl': tensor(2.6292), 'marker_mse': array(172.40337, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.7250347, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-16.2373)
# {'marker_ll': tensor(-5002.0234), 'time_ll': tensor(-196.5882), 'true_ll': tensor(-5198.6118), 'kl': tensor(2.6625), 'marker_mse': array(170.47758, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.7084036, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-16.5646)
# {'marker_ll': tensor(-5097.5933), 'time_ll': tensor(-205.6733), 'true_ll': tensor(-5303.2666), 'kl': tensor(2.5960), 'marker_mse': array(173.5129, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.57259, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-16.9001)
# {'marker_ll': tensor(-5202.1396), 'time_ll': tensor(-208.2973), 'true_ll': tensor(-5410.4370), 'kl': tensor(2.4023), 'marker_mse': array(169.57265, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.5330935, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-18.0585)
# {'marker_ll': tensor(-5571.6431), 'time_ll': tensor(-209.1903), 'true_ll': tensor(-5780.8335), 'kl': tensor(2.1241), 'marker_mse': array(162.50214, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.5377374, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-17.4922)
# {'marker_ll': tensor(-5397.9009), 'time_ll': tensor(-201.6303), 'true_ll': tensor(-5599.5312), 'kl': tensor(2.0124), 'marker_mse': array(166.3534, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.59033, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-16.9110)
# {'marker_ll': tensor(-5203.5869), 'time_ll': tensor(-209.9518), 'true_ll': tensor(-5413.5386), 'kl': tensor(2.0201), 'marker_mse': array(166.46854, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.456205, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-7.1713)
# {'marker_ll': tensor(-2091.3711), 'time_ll': tensor(-205.4669), 'true_ll': tensor(-2296.8379), 'kl': tensor(2.0345), 'marker_mse': array(182.91597, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.50862, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(11.6426)
# {'marker_ll': tensor(3927.7065), 'time_ll': tensor(-204.0792), 'true_ll': tensor(3723.6274), 'kl': tensor(2.0149), 'marker_mse': array(242.00665, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.7025824, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-11.1014)
# {'marker_ll': tensor(-3439.4087), 'time_ll': tensor(-115.5846), 'true_ll': tensor(-3554.9932), 'kl': tensor(2.5490), 'marker_mse': array(193.47487, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(8.9050665, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-9.1243)
# {'marker_ll': tensor(-2771.4424), 'time_ll': tensor(-152.0574), 'true_ll': tensor(-2923.4998), 'kl': tensor(3.7214), 'marker_mse': array(223.8228, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(8.281237, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-6.7756)
# {'marker_ll': tensor(-2035.0337), 'time_ll': tensor(-138.5116), 'true_ll': tensor(-2173.5452), 'kl': tensor(5.3606), 'marker_mse': array(262.5147, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.9910736, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-7.2793)
# {'marker_ll': tensor(-2245.7244), 'time_ll': tensor(-91.0473), 'true_ll': tensor(-2336.7717), 'kl': tensor(7.4109), 'marker_mse': array(270.1979, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(8.724407, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-7.4870)
# {'marker_ll': tensor(-2290.9253), 'time_ll': tensor(-114.6781), 'true_ll': tensor(-2405.6033), 'kl': tensor(9.7519), 'marker_mse': array(267.5938, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(8.39156, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-7.5537)
# {'marker_ll': tensor(-2295.9688), 'time_ll': tensor(-132.8590), 'true_ll': tensor(-2428.8276), 'kl': tensor(11.6290), 'marker_mse': array(247.52365, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(8.095246, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-7.7010)
# {'marker_ll': tensor(-2347.9106), 'time_ll': tensor(-128.3562), 'true_ll': tensor(-2476.2668), 'kl': tensor(11.9320), 'marker_mse': array(232.73581, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(8.570883, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-7.9883)
# {'marker_ll': tensor(-2435.3081), 'time_ll': tensor(-131.8647), 'true_ll': tensor(-2567.1729), 'kl': tensor(10.9308), 'marker_mse': array(220.49347, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(8.312168, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-8.2166)
# {'marker_ll': tensor(-2492.7820), 'time_ll': tensor(-145.7162), 'true_ll': tensor(-2638.4983), 'kl': tensor(9.1886), 'marker_mse': array(220.037, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.300012, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-8.5876)
# {'marker_ll': tensor(-2621.8345), 'time_ll': tensor(-133.7209), 'true_ll': tensor(-2755.5554), 'kl': tensor(7.5232), 'marker_mse': array(216.84227, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.6166034, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-9.1254)
# {'marker_ll': tensor(-2809.5723), 'time_ll': tensor(-116.5058), 'true_ll': tensor(-2926.0781), 'kl': tensor(5.9497), 'marker_mse': array(213.08844, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(8.233313, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-9.8666)
# {'marker_ll': tensor(-3016.9041), 'time_ll': tensor(-145.3086), 'true_ll': tensor(-3162.2126), 'kl': tensor(4.8895), 'marker_mse': array(206.30563, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(7.61294, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
# loss: tensor(-10.3816)
# {'marker_ll': tensor(-3161.0469), 'time_ll': tensor(-165.4654), 'true_ll': tensor(-3326.5122), 'kl': tensor(4.3974), 'marker_mse': array(201.8227, dtype=float32), 'marker_mse_count': array(320., dtype=float32), 'time_mse': array(6.9204073, dtype=float32), 'time_mse_count': array(288., dtype=float32)}
